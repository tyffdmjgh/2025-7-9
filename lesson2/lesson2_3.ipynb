# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import requests
from pprint import pprint
r = requests.get('https://api.github.com/events')
type(r)
pprint(r.text)
# Out:
# ('[{"id":"51955024133","type":"PushEvent","actor":{"id":129582520,"login":"rouge3877","display_login":"rouge3877","gravatar_id":"","url":"https://api.github.com/users/rouge3877","avatar_url":"https://avatars.githubusercontent.com/u/129582520?"},"repo":{"id":1015908261,"name":"RADIANT0312/DeepChess09","url":"https://api.github.com/repos/RADIANT0312/DeepChess09"},"payload":{"repository_id":1015908261,"push_id":25427844027,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"27e584ba6eac0449428b87b6c8d7015c92f2b0f6","before":"615ea37b9f3205bd2e9648e14fa97fec46aafe27","commits":[{"sha":"27e584ba6eac0449428b87b6c8d7015c92f2b0f6","author":{"email":"rouge_3877@outlook.com","name":"Yuxuan '
#  'Li"},"message":"fix: Refactor MainTopBar to TopBar and enhance slot '
#  'functionality in '
# ...
