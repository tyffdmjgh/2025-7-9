# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import requests
from pprint import pprint
r = requests.get('https://api.github.com/events')

if r.status_code == 200:
   print("下載成功")
   pprint(r.text)
else:
    print(404)
# Out:
# 下載成功
# ('[{"id":"52086950593","type":"PullRequestEvent","actor":{"id":44620177,"login":"thurtz","display_login":"thurtz","gravatar_id":"","url":"https://api.github.com/users/thurtz","avatar_url":"https://avatars.githubusercontent.com/u/44620177?"},"repo":{"id":976914220,"name":"thurtz/micro_X","url":"https://api.github.com/repos/thurtz/micro_X"},"payload":{"action":"opened","number":55,"pull_request":{"url":"https://api.github.com/repos/thurtz/micro_X/pulls/55","id":2665993832,"node_id":"PR_kwDOOjqHLM6e59Zo","html_url":"https://github.com/thurtz/micro_X/pull/55","diff_url":"https://github.com/thurtz/micro_X/pull/55.diff","patch_url":"https://github.com/thurtz/micro_X/pull/55.patch","issue_url":"https://api.github.com/repos/thurtz/micro_X/issues/55","number":55,"state":"open","locked":false,"title":"Added '
#  'activation of venv in '
# ...
