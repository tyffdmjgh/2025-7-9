# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import requests
from pprint import pprint

r = requests.get('https://api.github.com/events')
pprint(r.text)
# Out:
# ('[{"id":"51913458748","type":"PushEvent","actor":{"id":41911219,"login":"MarcEsteve","display_login":"MarcEsteve","gravatar_id":"","url":"https://api.github.com/users/MarcEsteve","avatar_url":"https://avatars.githubusercontent.com/u/41911219?"},"repo":{"id":930813730,"name":"MarcEsteve/bootcamp-techtalent-tgn2025","url":"https://api.github.com/repos/MarcEsteve/bootcamp-techtalent-tgn2025"},"payload":{"repository_id":930813730,"push_id":25407814360,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"28f7f2dafcaf038810a88831a95d83649fa2330a","before":"40f41fa696fa150917906d3c4b5bbe1c9e962cbc","commits":[{"sha":"28f7f2dafcaf038810a88831a95d83649fa2330a","author":{"email":"marc.esteve.garcia@gmail.com","name":"Marc '
#  'Esteve Garcia"},"message":"render de arrays con '
# ...
