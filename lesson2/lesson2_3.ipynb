# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import requests
from pprint import pprint
r = requests.get('https://api.github.com/events')

if r.status_code == 200:
   print("下載成功")
   pprint(r.text)
else:
    print(404)
# Out:
# 下載成功
# ('[{"id":"52373016928","type":"CreateEvent","actor":{"id":222157067,"login":"HueHueNT","display_login":"HueHueNT","gravatar_id":"","url":"https://api.github.com/users/HueHueNT","avatar_url":"https://avatars.githubusercontent.com/u/222157067?"},"repo":{"id":1024045895,"name":"HueHueNT/AutomationTest","url":"https://api.github.com/repos/HueHueNT/AutomationTest"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":"Fullstack '
#  'Selenium in Java '
# ...
