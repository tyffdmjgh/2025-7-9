# %%
import json
from pprint import pprint

# 打開並讀取 JSON 檔案
with  open('aqx_p_432.json', 'r', encoding='utf-8')as file:
    data = json.load(file)



# 顯示讀取後的資料（會是 Python 字典
pprint(data['records'])
# Out:
# [{'aqi': '38',
#   'co': '0.14',
#   'co_8hr': '0.2',
#   'county': '基隆市',
#   'latitude': '25.129167',
#   'longitude': '121.760056',
#   'no': '0.8',
#   'no2': '3',
#   'nox': '4.7',
#   'o3': '47',
#   'o3_8hr': '34',
#   'pm10': '23',
#   'pm10_avg': '23',
#   'pm2.5': '6',
#   'pm2.5_avg': '8.2',
#   'pollutant': '',
#   'publishtime': '2025/07/15 15:00:00',
#   'siteid': '1',
#   'sitename': '基隆',
#   'so2': '1.8',
#   'so2_avg': '1',
#   'status': '良好',
#   'wind_direc': '82',
#   'wind_speed': '2.3'},
#  {'aqi': '53',
#   'co': '0.16',
#   'co_8hr': '0.2',
#   'county': '新北市',
#   'latitude': '25.06624',
#   'longitude': '121.64081',
#   'no': '0.8',
#   'no2': '8',
#   'nox': '9.1',
#   'o3': '46',
#   'o3_8hr': '31',
#   'pm10': '25',
#   'pm10_avg': '23',
#   'pm2.5': '13',
#   'pm2.5_avg': '13.1',
#   'pollutant': '細懸浮微粒',
#   'publishtime': '2025/07/15 15:00:00',
#   'siteid': '2',
#   'sitename': '汐止',
#   'so2': '1.1',
#   'so2_avg': '0',
#   'status': '普通',
# ...
