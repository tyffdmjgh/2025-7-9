# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import requests
from pprint import pprint
r = requests.get('https://api.github.com/events')

if r.status_code == 200:
   print("下載成功")
   pprint(r.text)
else:
    print(404)
# Out:
# 下載成功
# ('[{"id":"53017976614","type":"PullRequestReviewCommentEvent","actor":{"id":41898282,"login":"github-actions[bot]","display_login":"github-actions","gravatar_id":"","url":"https://api.github.com/users/github-actions[bot]","avatar_url":"https://avatars.githubusercontent.com/u/41898282?"},"repo":{"id":1012515971,"name":"Nimba-Solutions/Delivery-Hub","url":"https://api.github.com/repos/Nimba-Solutions/Delivery-Hub"},"payload":{"action":"created","comment":{"url":"https://api.github.com/repos/Nimba-Solutions/Delivery-Hub/pulls/comments/2256908034","pull_request_review_id":3092175705,"id":2256908034,"node_id":"PRRC_kwDOPFnEg86Gha8C","diff_hunk":"@@ '
#  '-0,0 +1,101 @@\\n+public with sharing class DH_KanbanSettingsController '
#  '{\\n+\\n+    // Wrapper class to pass settings data to and from the '
#  'LWC\\n+    public class SettingsWrapper {\\n+        @AuraEnabled public '
#  'Boolean aiSuggestionsEnabled { get; set; }\\n+        @AuraEnabled public '
# ...
