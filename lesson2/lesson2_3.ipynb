# %%
import math
print(math.pi)
print(math.e)
# Out:
# 3.141592653589793
# 2.718281828459045

# %%
import requests
from pprint import pprint
r = requests.get('https://api.github.com/events')

if r.status_code == 200:
   print("下載成功")
   pprint(r.text)
else:
    print(404)
# Out:
# 下載成功
# ...
